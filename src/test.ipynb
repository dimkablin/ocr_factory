# %%
from ai_models.ocr import MODELS_FACTORY
import time
import matplotlib.pyplot as plt
import cv2
from utils import visualize

# %%
image = cv2.imread("data/test.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
print(image.shape)
# Out:
# (386, 915, 3)

# %%
start_time = time.time()
result =  MODELS_FACTORY([image])[0]
visualize.result2show(image, result)

# %%
MODELS_FACTORY.get_model_names()
# Out:
# ['Tesseract', 'Tesseract trained', 'EasyOCR', 'EasyOCR Trained']

# %%
MODELS_FACTORY.change_model("EasyOCR Trained")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# No Transformation module specified
# True

# %%
start_time = time.time()
result =  MODELS_FACTORY([image])[0]
visualize.result2show(image, result)
